# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys

# %%
swarm_data = glob.glob("*.npy", recursive=False)

# %%
print(swarm_data)
# Out:
# ['117-2018_results_arr.npy', '112-2018_results_arr.npy', '115-2018_results_arr.npy', '089-2018_results_arr.npy', '111-2018_results_arr.npy', '114-2018_results_arr.npy']

# %%
n_data = len(swarm_data)

# %%
arrays = []
for data in swarm_data:
    results_arr = np.load(data)
    arrays.append(results_arr)

summed = 0
for array in arrays:
    summed = summed + array

print(summed)
# Out:
# [[[[[1.0012376  0.32875764 1.8089689  ... 0.10344731 0.05203617
#      0.02440181]]
#
#    [[1.011978   0.33352342 1.8547263  ... 0.09980467 0.05065918
#      0.02382771]]
#
#    [[1.0116589  0.33080715 1.8519357  ... 0.09240295 0.04853861
#      0.0245461 ]]
#
#    ...
#
#    [[0.98803973 0.32365933 1.7752132  ... 0.09947466 0.05295885
#      0.02682638]]
#
#    [[1.0054071  0.33060277 1.8286229  ... 0.10258467 0.05696708
#      0.02480285]]
#
#    [[1.0012286  0.32843325 1.8211279  ... 0.09799252 0.04919619
#      0.02561301]]]
#
#
#   [[[1.0034225  0.32426208 1.8472619  ... 0.08876608 0.04685338
#      0.02227715]]
#
#    [[1.0155182  0.3340456  1.8623968  ... 0.09566186 0.04748924
#      0.02311114]]
#
#    [[1.0477872  0.3576125  1.9317973  ... 0.1170572  0.06113957
#      0.02484152]]
#
#    ...
#
#    [[1.021045   0.34508047 1.830264   ... 0.11713257 0.06241867
#      0.02839959]]
#
#    [[0.9681286  0.31126398 1.729394   ... 0.091636   0.04748373
#      0.02179901]]
#
# ...

# %%
data0 = np.load(swarm_data[0])
data1 = np.load(swarm_data[1])
data2 = np.load(swarm_data[2])
data3 = np.load(swarm_data[3])
data4 = np.load(swarm_data[4])
data5 = np.load(swarm_data[5])

# %%
print(data0)
# Out:
# [[[[[0.14199229 0.03828208 0.24953271 ... 0.00459502 0.00163551
#      0.00070093]]
#
#    [[0.14491236 0.03934404 0.25490654 ... 0.00389408 0.00147975
#      0.0008567 ]]
#
#    [[0.14684933 0.04013085 0.26401868 ... 0.0038162  0.00147975
#      0.00093458]]
#
#    ...
#
#    [[0.1446208  0.0390527  0.25950155 ... 0.00342679 0.00147975
#      0.0008567 ]]
#
#    [[0.14485064 0.03932716 0.25856698 ... 0.00428349 0.0017134
#      0.00093458]]
#
#    [[0.1470046  0.0401768  0.26666668 ... 0.00420561 0.00109034
#      0.00062305]]]
#
#
#   [[[0.14534563 0.03936592 0.26300624 ... 0.0038162  0.00147975
#      0.00070093]]
#
#    [[0.1482402  0.04094554 0.26830217 ... 0.00451713 0.00116822
#      0.00062305]]
#
#    [[0.14753036 0.04037636 0.2660436  ... 0.00412773 0.00147975
#      0.00070093]]
#
#    ...
#
#    [[0.14164142 0.03768444 0.24820872 ... 0.00334891 0.00147975
#      0.00062305]]
#
#    [[0.14572303 0.03992787 0.25895637 ... 0.00389408 0.00163551
#      0.00062305]]
#
# ...

# %%
for num in range(n_data):
    arrs = np.load(swarm_data[num])

# %%
total = data1 + data2 + data3 + data4 + data5 + data6

# %%
print(total)
# Out:
# [[[[[1.0012376  0.32875764 1.8089689  ... 0.10344731 0.05203617
#      0.02440181]]
#
#    [[1.011978   0.33352342 1.8547263  ... 0.09980467 0.05065918
#      0.02382771]]
#
#    [[1.0116589  0.33080715 1.8519357  ... 0.09240295 0.04853861
#      0.0245461 ]]
#
#    ...
#
#    [[0.98803973 0.32365933 1.7752132  ... 0.09947466 0.05295885
#      0.02682638]]
#
#    [[1.0054071  0.33060277 1.8286229  ... 0.10258467 0.05696708
#      0.02480285]]
#
#    [[1.0012286  0.32843325 1.8211279  ... 0.09799252 0.04919619
#      0.02561301]]]
#
#
#   [[[1.0034225  0.32426208 1.8472619  ... 0.08876608 0.04685338
#      0.02227715]]
#
#    [[1.0155182  0.3340456  1.8623968  ... 0.09566186 0.04748924
#      0.02311114]]
#
#    [[1.0477872  0.3576125  1.9317973  ... 0.1170572  0.06113957
#      0.02484152]]
#
#    ...
#
#    [[1.021045   0.34508047 1.830264   ... 0.11713257 0.06241867
#      0.02839959]]
#
#    [[0.9681286  0.31126398 1.729394   ... 0.091636   0.04748373
#      0.02179901]]
#
# ...

# %%
print(summed)
# Out:
# [[[[[1.0012376  0.32875764 1.8089689  ... 0.10344731 0.05203617
#      0.02440181]]
#
#    [[1.011978   0.33352342 1.8547263  ... 0.09980467 0.05065918
#      0.02382771]]
#
#    [[1.0116589  0.33080715 1.8519357  ... 0.09240295 0.04853861
#      0.0245461 ]]
#
#    ...
#
#    [[0.98803973 0.32365933 1.7752132  ... 0.09947466 0.05295885
#      0.02682638]]
#
#    [[1.0054071  0.33060277 1.8286229  ... 0.10258467 0.05696708
#      0.02480285]]
#
#    [[1.0012286  0.32843325 1.8211279  ... 0.09799252 0.04919619
#      0.02561301]]]
#
#
#   [[[1.0034225  0.32426208 1.8472619  ... 0.08876608 0.04685338
#      0.02227715]]
#
#    [[1.0155182  0.3340456  1.8623968  ... 0.09566186 0.04748924
#      0.02311114]]
#
#    [[1.0477872  0.3576125  1.9317973  ... 0.1170572  0.06113957
#      0.02484152]]
#
#    ...
#
#    [[1.021045   0.34508047 1.830264   ... 0.11713257 0.06241867
#      0.02839959]]
#
#    [[0.9681286  0.31126398 1.729394   ... 0.091636   0.04748373
#      0.02179901]]
#
# ...
